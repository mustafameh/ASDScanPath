# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np

# %%
train_datagen = ImageDataGenerator(
     rescale=1./255,
    validation_split=0.20)

train_generator = train_datagen.flow_from_directory(
    r"C:\Users\786me\Desktop\FinalYearProject\ASDScanPath\ASD\Contrasted",
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    subset='training') # set as training data

validation_generator = train_datagen.flow_from_directory(
    r"C:\Users\786me\Desktop\FinalYearProject\ASDScanPath\ASD\Contrasted", # same directory as training data
    target_size=(224 , 224),
    batch_size=32,
    class_mode='binary',
    subset='validation') # set as validation data

img_size = (224, 224 , 3)
# Out:
# Found 439 images belonging to 2 classes.
# Found 108 images belonging to 2 classes.

# %%
x_batch, y_batch = train_generator.next()
for i in range(4):
    image = x_batch[i]
    plt.subplot(2, 2, i+1)
    plt.imshow(image)
    
plt.show()

# %%
base_model = MobileNetV3Small(input_shape=img_size, include_top=False, weights='imagenet')

#Freeze weights 
for layer in base_model.layers[1:100]:
    layer.trainable = False


for i,layer in enumerate(base_model.layers):
    print(i,layer.name,layer.trainable)
# Out:
# 0 input_1 True
# 1 rescaling False
# 2 Conv False
# 3 Conv/BatchNorm False
# 4 tf.__operators__.add False
# 5 re_lu False
# 6 tf.math.multiply False
# 7 multiply False
# 8 expanded_conv/depthwise/pad False
# 9 expanded_conv/depthwise False
# 10 expanded_conv/depthwise/BatchNorm False
# 11 re_lu_1 False
# 12 expanded_conv/squeeze_excite/AvgPool False
# 13 expanded_conv/squeeze_excite/Conv False
# 14 expanded_conv/squeeze_excite/Relu False
# 15 expanded_conv/squeeze_excite/Conv_1 False
# 16 tf.__operators__.add_1 False
# 17 re_lu_2 False
# 18 tf.math.multiply_1 False
# 19 expanded_conv/squeeze_excite/Mul False
# 20 expanded_conv/project False
# 21 expanded_conv/project/BatchNorm False
# 22 expanded_conv_1/expand False
# 23 expanded_conv_1/expand/BatchNorm False
# 24 re_lu_3 False
# 25 expanded_conv_1/depthwise/pad False
# 26 expanded_conv_1/depthwise False
# 27 expanded_conv_1/depthwise/BatchNorm False
# 28 re_lu_4 False
# 29 expanded_conv_1/project False
# 30 expanded_conv_1/project/BatchNorm False
# 31 expanded_conv_2/expand False
# 32 expanded_conv_2/expand/BatchNorm False
# 33 re_lu_5 False
# 34 expanded_conv_2/depthwise False
# 35 expanded_conv_2/depthwise/BatchNorm False
# 36 re_lu_6 False
# 37 expanded_conv_2/project False
# 38 expanded_conv_2/project/BatchNorm False
# 39 expanded_conv_2/Add False
# 40 expanded_conv_3/expand False
# 41 expanded_conv_3/expand/BatchNorm False
# 42 tf.__operators__.add_2 False
# 43 re_lu_7 False
# 44 tf.math.multiply_2 False
# 45 multiply_1 False
# 46 expanded_conv_3/depthwise/pad False
# 47 expanded_conv_3/depthwise False
# 48 expanded_conv_3/depthwise/BatchNorm False
# 49 tf.__operators__.add_3 False
# 50 re_lu_8 False
# 51 tf.math.multiply_3 False
# 52 multiply_2 False
# 53 expanded_conv_3/squeeze_excite/AvgPool False
# 54 expanded_conv_3/squeeze_excite/Conv False
# 55 expanded_conv_3/squeeze_excite/Relu False
# 56 expanded_conv_3/squeeze_excite/Conv_1 False
# 57 tf.__operators__.add_4 False
# 58 re_lu_9 False
# 59 tf.math.multiply_4 False
# 60 expanded_conv_3/squeeze_excite/Mul False
# 61 expanded_conv_3/project False
# 62 expanded_conv_3/project/BatchNorm False
# 63 expanded_conv_4/expand False
# 64 expanded_conv_4/expand/BatchNorm False
# 65 tf.__operators__.add_5 False
# 66 re_lu_10 False
# 67 tf.math.multiply_5 False
# 68 multiply_3 False
# 69 expanded_conv_4/depthwise False
# 70 expanded_conv_4/depthwise/BatchNorm False
# 71 tf.__operators__.add_6 False
# 72 re_lu_11 False
# 73 tf.math.multiply_6 False
# 74 multiply_4 False
# 75 expanded_conv_4/squeeze_excite/AvgPool False
# 76 expanded_conv_4/squeeze_excite/Conv False
# 77 expanded_conv_4/squeeze_excite/Relu False
# 78 expanded_conv_4/squeeze_excite/Conv_1 False
# 79 tf.__operators__.add_7 False
# 80 re_lu_12 False
# 81 tf.math.multiply_7 False
# 82 expanded_conv_4/squeeze_excite/Mul False
# 83 expanded_conv_4/project False
# 84 expanded_conv_4/project/BatchNorm False
# 85 expanded_conv_4/Add False
# 86 expanded_conv_5/expand False
# 87 expanded_conv_5/expand/BatchNorm False
# 88 tf.__operators__.add_8 False
# 89 re_lu_13 False
# 90 tf.math.multiply_8 False
# 91 multiply_5 False
# 92 expanded_conv_5/depthwise False
# 93 expanded_conv_5/depthwise/BatchNorm False
# 94 tf.__operators__.add_9 False
# 95 re_lu_14 False
# 96 tf.math.multiply_9 False
# 97 multiply_6 False
# 98 expanded_conv_5/squeeze_excite/AvgPool False
# 99 expanded_conv_5/squeeze_excite/Conv False
# 100 expanded_conv_5/squeeze_excite/Relu True
# 101 expanded_conv_5/squeeze_excite/Conv_1 True
# 102 tf.__operators__.add_10 True
# 103 re_lu_15 True
# 104 tf.math.multiply_10 True
# 105 expanded_conv_5/squeeze_excite/Mul True
# 106 expanded_conv_5/project True
# 107 expanded_conv_5/project/BatchNorm True
# 108 expanded_conv_5/Add True
# 109 expanded_conv_6/expand True
# 110 expanded_conv_6/expand/BatchNorm True
# 111 tf.__operators__.add_11 True
# 112 re_lu_16 True
# 113 tf.math.multiply_11 True
# 114 multiply_7 True
# 115 expanded_conv_6/depthwise True
# 116 expanded_conv_6/depthwise/BatchNorm True
# 117 tf.__operators__.add_12 True
# 118 re_lu_17 True
# 119 tf.math.multiply_12 True
# 120 multiply_8 True
# 121 expanded_conv_6/squeeze_excite/AvgPool True
# 122 expanded_conv_6/squeeze_excite/Conv True
# 123 expanded_conv_6/squeeze_excite/Relu True
# 124 expanded_conv_6/squeeze_excite/Conv_1 True
# 125 tf.__operators__.add_13 True
# 126 re_lu_18 True
# 127 tf.math.multiply_13 True
# 128 expanded_conv_6/squeeze_excite/Mul True
# 129 expanded_conv_6/project True
# 130 expanded_conv_6/project/BatchNorm True
# 131 expanded_conv_7/expand True
# 132 expanded_conv_7/expand/BatchNorm True
# 133 tf.__operators__.add_14 True
# 134 re_lu_19 True
# 135 tf.math.multiply_14 True
# 136 multiply_9 True
# 137 expanded_conv_7/depthwise True
# 138 expanded_conv_7/depthwise/BatchNorm True
# 139 tf.__operators__.add_15 True
# 140 re_lu_20 True
# 141 tf.math.multiply_15 True
# 142 multiply_10 True
# 143 expanded_conv_7/squeeze_excite/AvgPool True
# 144 expanded_conv_7/squeeze_excite/Conv True
# 145 expanded_conv_7/squeeze_excite/Relu True
# 146 expanded_conv_7/squeeze_excite/Conv_1 True
# 147 tf.__operators__.add_16 True
# 148 re_lu_21 True
# 149 tf.math.multiply_16 True
# 150 expanded_conv_7/squeeze_excite/Mul True
# 151 expanded_conv_7/project True
# 152 expanded_conv_7/project/BatchNorm True
# 153 expanded_conv_7/Add True
# 154 expanded_conv_8/expand True
# 155 expanded_conv_8/expand/BatchNorm True
# 156 tf.__operators__.add_17 True
# 157 re_lu_22 True
# 158 tf.math.multiply_17 True
# 159 multiply_11 True
# 160 expanded_conv_8/depthwise/pad True
# 161 expanded_conv_8/depthwise True
# 162 expanded_conv_8/depthwise/BatchNorm True
# 163 tf.__operators__.add_18 True
# 164 re_lu_23 True
# 165 tf.math.multiply_18 True
# 166 multiply_12 True
# 167 expanded_conv_8/squeeze_excite/AvgPool True
# 168 expanded_conv_8/squeeze_excite/Conv True
# 169 expanded_conv_8/squeeze_excite/Relu True
# 170 expanded_conv_8/squeeze_excite/Conv_1 True
# 171 tf.__operators__.add_19 True
# 172 re_lu_24 True
# 173 tf.math.multiply_19 True
# 174 expanded_conv_8/squeeze_excite/Mul True
# 175 expanded_conv_8/project True
# 176 expanded_conv_8/project/BatchNorm True
# 177 expanded_conv_9/expand True
# 178 expanded_conv_9/expand/BatchNorm True
# 179 tf.__operators__.add_20 True
# 180 re_lu_25 True
# 181 tf.math.multiply_20 True
# 182 multiply_13 True
# 183 expanded_conv_9/depthwise True
# 184 expanded_conv_9/depthwise/BatchNorm True
# 185 tf.__operators__.add_21 True
# 186 re_lu_26 True
# 187 tf.math.multiply_21 True
# 188 multiply_14 True
# 189 expanded_conv_9/squeeze_excite/AvgPool True
# 190 expanded_conv_9/squeeze_excite/Conv True
# 191 expanded_conv_9/squeeze_excite/Relu True
# 192 expanded_conv_9/squeeze_excite/Conv_1 True
# 193 tf.__operators__.add_22 True
# 194 re_lu_27 True
# 195 tf.math.multiply_22 True
# 196 expanded_conv_9/squeeze_excite/Mul True
# 197 expanded_conv_9/project True
# 198 expanded_conv_9/project/BatchNorm True
# 199 expanded_conv_9/Add True
# 200 expanded_conv_10/expand True
# 201 expanded_conv_10/expand/BatchNorm True
# 202 tf.__operators__.add_23 True
# 203 re_lu_28 True
# 204 tf.math.multiply_23 True
# 205 multiply_15 True
# 206 expanded_conv_10/depthwise True
# 207 expanded_conv_10/depthwise/BatchNorm True
# 208 tf.__operators__.add_24 True
# 209 re_lu_29 True
# 210 tf.math.multiply_24 True
# 211 multiply_16 True
# 212 expanded_conv_10/squeeze_excite/AvgPool True
# 213 expanded_conv_10/squeeze_excite/Conv True
# 214 expanded_conv_10/squeeze_excite/Relu True
# 215 expanded_conv_10/squeeze_excite/Conv_1 True
# 216 tf.__operators__.add_25 True
# 217 re_lu_30 True
# 218 tf.math.multiply_25 True
# 219 expanded_conv_10/squeeze_excite/Mul True
# 220 expanded_conv_10/project True
# 221 expanded_conv_10/project/BatchNorm True
# 222 expanded_conv_10/Add True
# 223 Conv_1 True
# 224 Conv_1/BatchNorm True
# 225 tf.__operators__.add_26 True
# 226 re_lu_31 True
# 227 tf.math.multiply_26 True
# 228 multiply_17 True

# %%
model = tf.keras.Sequential([
    base_model,tf.keras.layers.Dropout(0.2)
])
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(units= 128, activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units= 1, activation = 'sigmoid'))
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer = opt, loss = 'binary_focal_crossentropy', metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  MobilenetV3small (Functiona  (None, 7, 7, 576)        939120
#  l)
#
#  dropout (Dropout)           (None, 7, 7, 576)         0
#
#  flatten (Flatten)           (None, 28224)             0
#
#  dense (Dense)               (None, 128)               3612800
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 4,552,049
# Trainable params: 4,426,465
# Non-trainable params: 125,584
# _________________________________________________________________

# %%
history = model.fit(train_generator, validation_data=validation_generator, epochs = 20)
# Out:
# Epoch 1/20
# 14/14 [==============================] - 15s 531ms/step - loss: 1.1281 - accuracy: 0.5626 - val_loss: 0.1920 - val_accuracy: 0.6019
# Epoch 2/20
# 14/14 [==============================] - 6s 430ms/step - loss: 0.2183 - accuracy: 0.6606 - val_loss: 0.1887 - val_accuracy: 0.6019
# Epoch 3/20
# 14/14 [==============================] - 6s 424ms/step - loss: 0.1660 - accuracy: 0.6743 - val_loss: 0.1826 - val_accuracy: 0.6019
# Epoch 4/20
# 14/14 [==============================] - 6s 425ms/step - loss: 0.1452 - accuracy: 0.6925 - val_loss: 0.1781 - val_accuracy: 0.6019
# Epoch 5/20
# 14/14 [==============================] - 6s 419ms/step - loss: 0.1435 - accuracy: 0.6993 - val_loss: 0.1760 - val_accuracy: 0.6019
# Epoch 6/20
# 14/14 [==============================] - 6s 419ms/step - loss: 0.1433 - accuracy: 0.6902 - val_loss: 0.1743 - val_accuracy: 0.6019
# Epoch 7/20
# 14/14 [==============================] - 6s 420ms/step - loss: 0.1425 - accuracy: 0.7153 - val_loss: 0.1725 - val_accuracy: 0.6019
# Epoch 8/20
# 14/14 [==============================] - 6s 424ms/step - loss: 0.1337 - accuracy: 0.7335 - val_loss: 0.1721 - val_accuracy: 0.6019
# Epoch 9/20
# 14/14 [==============================] - 6s 442ms/step - loss: 0.1375 - accuracy: 0.7403 - val_loss: 0.1765 - val_accuracy: 0.6019
# Epoch 10/20
# 14/14 [==============================] - 6s 431ms/step - loss: 0.1362 - accuracy: 0.7403 - val_loss: 0.1750 - val_accuracy: 0.6019
# Epoch 11/20
# 14/14 [==============================] - 7s 510ms/step - loss: 0.1328 - accuracy: 0.7540 - val_loss: 0.1709 - val_accuracy: 0.6019
# Epoch 12/20
# 14/14 [==============================] - 6s 442ms/step - loss: 0.1329 - accuracy: 0.7426 - val_loss: 0.1707 - val_accuracy: 0.6019
# Epoch 13/20
# 14/14 [==============================] - 6s 408ms/step - loss: 0.1315 - accuracy: 0.7312 - val_loss: 0.1705 - val_accuracy: 0.6019
# Epoch 14/20
# 14/14 [==============================] - 6s 409ms/step - loss: 0.1272 - accuracy: 0.7517 - val_loss: 0.1699 - val_accuracy: 0.6019
# Epoch 15/20
# 14/14 [==============================] - 6s 422ms/step - loss: 0.1264 - accuracy: 0.7745 - val_loss: 0.1694 - val_accuracy: 0.6019
# Epoch 16/20
# 14/14 [==============================] - 6s 453ms/step - loss: 0.1245 - accuracy: 0.7631 - val_loss: 0.1692 - val_accuracy: 0.6019
# Epoch 17/20
# 14/14 [==============================] - 6s 411ms/step - loss: 0.1292 - accuracy: 0.7585 - val_loss: 0.1690 - val_accuracy: 0.6019
# Epoch 18/20
# 14/14 [==============================] - 6s 427ms/step - loss: 0.1281 - accuracy: 0.7540 - val_loss: 0.1685 - val_accuracy: 0.6019
# Epoch 19/20
# 14/14 [==============================] - 6s 413ms/step - loss: 0.1261 - accuracy: 0.7449 - val_loss: 0.1683 - val_accuracy: 0.6019
# Epoch 20/20
# 14/14 [==============================] - 6s 411ms/step - loss: 0.1250 - accuracy: 0.7380 - val_loss: 0.1685 - val_accuracy: 0.6019

# %%
##Confusion Matrix Generator and ROC Curve
y_pred_real = model.predict(validation_generator)
y_pred = [int(p >= 0.5) for p in y_pred_real] ##With sigmoid 1 neuron
##y_pred = np.argmax(Y_pred, axis=1) ##With softmax and 2 neurons 
y_true = validation_generator.classes
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(validation_generator.classes, y_pred)
print(cm)
# Out:
# 4/4 [==============================] - 2s 177ms/step
# [[65  0]
#  [43  0]]
